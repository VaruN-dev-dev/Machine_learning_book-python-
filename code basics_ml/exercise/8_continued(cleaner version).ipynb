# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("HR_comma_sep.csv")
df.head(5)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
dummy = pd.get_dummies(df.salary)
new_df = pd.concat([df , dummy] , axis = 1)
new_df.head(5)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary  high  low  medium
# ...

# %%
new_df = new_df.drop(columns = ["salary" ,"last_evaluation" , "number_project" , "time_spend_company" , "Work_accident" , "Department"] , axis = 1)
new_df.head(5)
# Out:
#    satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                0.38                   157     1                      0
# 1                0.80                   262     1                      0
# 2                0.11                   272     1                      0
# 3                0.72                   223     1                      0
# 4                0.37                   159     1                      0
#
#    high  low  medium
# 0     0    1       0
# 1     0    0       1
# 2     0    0       1
# 3     0    1       0
# 4     0    1       0

# %%
from sklearn.model_selection import train_test_split
x = new_df.drop(columns = ["left"] , axis = 1)
y = new_df.left
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(x_test , y_test)
# Out:
# 0.7793333333333333
