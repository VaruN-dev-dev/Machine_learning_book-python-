# %%
from matplotlib.colors import ListedColormap
custom_cmap = ListedColormap(['#fafab0','#9898ff','#a0faa0'])

meshgrid(linspace()) # yk for plotting

sns.set_theme(style="darkgrid")

linspace() # really important

np.c_, .ravel(), np.ones() 

np.random.randn(), np.random.rand # one is nornal distrubution and other is uniform 

linear_model :
    
    Regressions :
        
        LinearRegression() # note this uses SVD not gradient descent
        SGDRegressor(max_iter, tol, penalty, eta=0.1) # this uses gradient descent
        
        regularized one :
            
            # remember these all can be implemented like SGDRegressor(some_hyperparameteres)
            Ridge(alpha=1, solver="cholesky")
            Lasso(alpha=0.1)
            ElasticNet(alpha=0.1, l1_ration=0.5) # it is mix of the 2
            SGDRegressor(l1_ration=0.5, alpha=0/5)
            
        SGDRegressor(penalty="l2") # this uses gradient descent
        SGDRegressor(l1_ration=0.5, alpha=0.5) # same as above for elastic net
    
    Classification :
        
        # for non linear you can use polyfeatures
        LogisticRegression() # can also be regularized see docs
        LogisticRegression(solver="lbfgs", C=10**10, random_state=42)
        softmax_reg = LogisticRegression(multi_class="multinomial", solver="lbfgs", C=10) # softmax regression
        
svm :
    
    # LinearSVC/SVR is preferred over kernel="linear" cause it provide more options
    
    Classification :
        
        SVC(kernel="linear",C) # linear, poly..
        # for non linear you can use polyfeatures with linearSVC or use SVC(kernel="poly")
        LinearSVC(C=1, loss="hinge", random_state=42, max_iter-10000) # you can also use polynomial features
        SVC(kernel="poly", degree=3, coef=1. C=5)
        # The hyperparameter coef0 controls how much the model is influenced by highdegree
        # polynomials versus low-degree polynomials.
        # there are other kernel also rbf and all
    
    Regressions :
        
        # same here can also use poly yk..
        LinearSVR(epsilon=1.5, random_state=42)
        SVR(kernel="poly", degree=2, C=100, epsilon=0.1, gamma="scale")
    
DecisionTreeClassifier :
    DecisionTreeClassifier(max_depth=2, random_state=42)
    
DecisionTreeRegressor :
    DecisionTreeRegressor(random_state=42, max_depth=2)

preprocessing :
    
    PloynomialFeatures(degree, include_bias)
    StandardScaler()
    
metrics :
    
    mean_squared_error # use np.sqrt for RSME yk.
    
model_selection :
    
    train_test_split
